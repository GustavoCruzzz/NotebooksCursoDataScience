# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoCruzzz/NotebooksCursoDataScience/blob/main/Estat%C3%ADstica_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Amostragem Simples***

# %%
import pandas as pd
import numpy as np

# %%
base = pd.read_csv('iris.csv')
base
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
base.shape
# Out:
# (150, 5)

# %%
np.random.seed(2345)

amostra = np.random.choice(a = [0, 1], size = 150, replace = True,
                           p = [0.7, 0.3],
                           )
len(amostra)
len(amostra[amostra == 1])
len(amostra[amostra == 0])
# Out:
# 101

# %%
base_final = base.loc[amostra == 0]
base_final.shape
# Out:
# (101, 5)

# %%
base_final
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
#
# [101 rows x 5 columns]

# %%
base_final2 = base.loc[amostra == 1]
base_final2.shape
# Out:
# (49, 5)

# %%
base_final2
# Out:
#      sepal length  sepal width  petal length  petal width            class
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 18            5.7          3.8           1.7          0.3      Iris-setosa
# 19            5.1          3.8           1.5          0.3      Iris-setosa
# 20            5.4          3.4           1.7          0.2      Iris-setosa
# 23            5.1          3.3           1.7          0.5      Iris-setosa
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# 25            5.0          3.0           1.6          0.2      Iris-setosa
# ...

# %% [markdown]
# # ***Amostragem Sistemática***

# %%
import numpy as np
import pandas as pd
from math import ceil

# %%
populacao = 150
amostra = 15
k = ceil(populacao / amostra)
print(k)
# Out:
# 10

# %%
r = np.random.randint(low = 1, high = k + 1, size = 1)
print(r)
# Out:
# [2]

# %%
acumulador = r[0]
sorteados = []
for i in range(amostra):
    sorteados.append(acumulador)
    acumulador += k
print(sorteados)
# Out:
# [np.int64(2), np.int64(12), np.int64(22), np.int64(32), np.int64(42), np.int64(52), np.int64(62), np.int64(72), np.int64(82), np.int64(92), np.int64(102), np.int64(112), np.int64(122), np.int64(132), np.int64(142)]

# %%
len(sorteados)
# Out:
# 15

# %%
base = pd.read_csv('iris.csv')
base_final = base.loc[sorteados]
base_final
# Out:
#      sepal length  sepal width  petal length  petal width            class
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 12            4.8          3.0           1.4          0.1      Iris-setosa
# 22            4.6          3.6           1.0          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 92            5.8          2.6           4.0          1.2  Iris-versicolor
# 102           7.1          3.0           5.9          2.1   Iris-virginica
# ...

# %% [markdown]
# # ***Amostragem Estratificada***

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv('iris.csv')
iris['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
X, _, y, _, = train_test_split(iris.iloc[:, 0:4], iris.iloc[:, 4],
                               test_size = 0.5, stratify = iris.iloc[:, 4])
y.value_counts()
# Out:
# class
# Iris-setosa        25
# Iris-versicolor    25
# Iris-virginica     25
# Name: count, dtype: int64

# %%
infert = pd.read_csv('infert.csv')
infert
# Out:
#      Unnamed: 0 education  age  parity  induced  case  spontaneous  stratum  \
# 0             1    0-5yrs   26       6        1     1            2        1
# 1             2    0-5yrs   42       1        1     1            0        2
# 2             3    0-5yrs   39       6        2     1            0        3
# 3             4    0-5yrs   34       4        2     1            0        4
# 4             5   6-11yrs   35       3        1     1            1        5
# ..          ...       ...  ...     ...      ...   ...          ...      ...
# 243         244   12+ yrs   31       1        0     0            1       79
# 244         245   12+ yrs   34       1        0     0            0       80
# 245         246   12+ yrs   35       2        2     0            0       81
# 246         247   12+ yrs   29       1        0     0            1       82
# 247         248   12+ yrs   23       1        0     0            1       83
#
#      pooled.stratum
# 0                 3
# ...

# %%
infert['education'].value_counts()
# Out:
# education
# 6-11yrs    120
# 12+ yrs    116
# 0-5yrs      12
# Name: count, dtype: int64

# %%
x1, _, y1, _, = train_test_split(infert.iloc[:, 2:9], infert.iloc[:, 1],
                                  test_size = 0.6, stratify = infert.iloc[:, 1])
y1.value_counts()
# Out:
# education
# 6-11yrs    48
# 12+ yrs    46
# 0-5yrs      5
# Name: count, dtype: int64

# %% [markdown]
# # ***Medidas de Centralidade e Variabilidade***

# %%
import numpy as np
from scipy import stats

# %%
jogadores = [40000, 18000, 12000, 250000, 30000, 140000, 300000, 40000, 800000]
np.mean(jogadores)
# Out:
# np.float64(181111.11111111112)

# %%
np.median(jogadores)
# Out:
# np.float64(40000.0)

# %%
quartis = np.quantile(jogadores, [0, 0.25, 0.5, 0.75, 1])
quartis
# Out:
# array([ 12000.,  30000.,  40000., 250000., 800000.])

# %%
np.std(jogadores, ddof = 1)
# Out:
# np.float64(255307.87514511007)

# %%
stats.describe(jogadores)
# Out:
# DescribeResult(nobs=np.int64(9), minmax=(np.int64(12000), np.int64(800000)), mean=np.float64(181111.11111111112), variance=np.float64(65182111111.11111), skewness=np.float64(1.758635899846188), kurtosis=np.float64(1.9572075427527729))

# %% [markdown]
# # ***DISTRIBUIÇÃO NORMAL***

# %%
from scipy.stats import norm

# %%
norm.cdf(6,8,2)
# Out:
# np.float64(0.15865525393145707)

# %%
norm.sf(6,8,2)
1 - norm.cdf(6,8,2)
# Out:
# np.float64(0.8413447460685429)

# %%
norm.cdf(6,8,2) + norm.sf(10,8,2)
# Out:
# np.float64(0.31731050786291415)

# %%
norm.cdf(10,8,2) - norm.sf(8,8,2)
# Out:
# np.float64(0.3413447460685429)

# %% [markdown]
# # ***TESTES DE NORMALIDADE***

# %%
from scipy import stats
from scipy.stats import norm
from scipy.stats import skewnorm
import matplotlib.pyplot as plt

# %%
dados = norm.rvs(size = 1000)
dados
# Out:
# array([ 1.46033316e+00,  9.90230635e-01, -8.49321425e-01,  4.43166490e-01,
#        -8.85054386e-01,  1.05458935e+00, -1.71799732e+00, -8.68105915e-01,
#        -1.03472451e+00, -8.56576088e-01, -4.07678309e-01,  3.11405758e-01,
#        -1.77560131e+00,  3.59548373e-01, -8.69772798e-01,  4.39324508e-01,
#         2.71026594e-01,  6.32504871e-01,  7.05123811e-01, -9.26900976e-01,
#         7.39151784e-01, -1.19482191e+00,  6.49760027e-01, -6.72726996e-01,
#         9.62818153e-01, -1.42710415e+00, -5.97113511e-01,  7.57044221e-01,
#         3.10602303e-01, -1.90804670e-01, -8.20824890e-01, -4.43611256e-01,
#         4.80096491e-01,  1.11125895e+00, -9.68338119e-01,  2.27201428e-01,
#        -4.70743840e-01,  2.04474624e+00,  2.72166811e-01, -9.24649080e-01,
#         1.36593123e+00,  5.32031805e-01,  7.41093238e-01,  1.00136327e+00,
#         4.60661743e-01,  1.29356270e-01,  5.23146320e-01, -2.63244502e+00,
# ...

# %%
plt.hist(dados, bins=20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
fig, ax = plt.subplots()
stats.probplot(dados, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(dados)
# Out:
# ShapiroResult(statistic=np.float64(0.99846447724453), pvalue=np.float64(0.531650872929938))

# %%
dados2=skewnorm.rvs(4, size=1000)
plt.hist(dados2, bins=20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
fig, ax = plt.subplots()
stats.probplot(dados2, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(dados2)
# Out:
# ShapiroResult(statistic=np.float64(0.9715024980549021), pvalue=np.float64(4.212332493722396e-13))
